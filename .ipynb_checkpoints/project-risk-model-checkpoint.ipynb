# %% [markdown]
# # Predicting project risk
#
# The objetive of this work is design a machine learning model to predict the probability of a project having issues worth being featured in the project management risk report. We also want to explore the most significant factors that contribute to project risk, like managers, scope, seasonality, etc.
#
# The dataset `project-data.csv` used in this model is preprocessed in the notebook `project-risk-features.ipynb`. This dataset has the following attributes:
#
# * `project`: project identifier
# * `risk`: label: 1 - high risk, 0 - low risk
# * `status`: project status: {'tramitando para contratação', 'em andamento', 'não iniciado', 'sem relatório', 'atrasado', 'dependência externa', 'suspenso', 'em dependência externa', 'cancelado', 'em fase de encerramento', 'atividade', 'sem informação'}
# * `compliance`: index for compliance with project management process
# * `report_count`: number of reports available for the project
# * `has_schedule`: 1 - project has schedule, 0 - otherwise
# * `scope`: project scope: {"Corporativo", "Setorial", "Estruturante"}
# * `office`: project sponsor office: {'Corporativo', 'CENIN', 'SECOM', 'DILEG', 'DG', 'DIRAD', 'DRH'}
# * `month`: month of project report publication
# * `year`: year of project report publication
# * `day`: day of project report publication
# * `risk_previous1`: project appeared in the risk report in the last month
# * `risk_previous2`: project appeared in the risk report in the last two months
# * `risk_previous3`: project appeared in the risk report in the last three months
# * `project_risk_likelihood`: maximum likelihood risk probability estimation (with Laplace smoothing)
# * `report_word_count`: number of words in report
# * `poa_word_count`: number of words in "points of attention" section
# * `estimated_days_finish`: estimated days to finish project
# * `manager_risk_likelihood`: maximum likelihood risk probability estimation for managers (with Laplace smoothing)
# * `manager_project_count`: number of projects the manager is responsible in a given month
#
# ## Preprocessing

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy as sp
import util
from IPython.display import display
from sklearn.feature_selection import SelectKBest, f_classif, SelectFromModel
from sklearn.cross_validation import StratifiedKFold, cross_val_score, cross_val_predict
from sklearn.svm import LinearSVC, SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import ExtraTreesClassifier, VotingClassifier
from sklearn import metrics
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.grid_search import GridSearchCV
from sklearn.preprocessing import binarize
from sklearn.preprocessing import StandardScaler

data = pd.read_csv('project-data.csv')

# encoding categorical data
data = pd.concat([data, pd.get_dummies(data.status)], axis=1)
data = pd.concat([data, pd.get_dummies(data.office.str.lower())], axis=1)

# filling missing values
data['compliance'].fillna(data['compliance'].mean(), inplace=True)
data['report_count'].fillna(data['report_count'].mean(), inplace=True)

# standardization
numerical_features = ['day', 'report_word_count', 'poa_word_count', 'compliance',
                      'estimated_days_finish', 'manager_risk_likelihood', 'manager_project_count',
                      'project_risk_likelihood', 'report_count']

std_scale = StandardScaler().fit(data[numerical_features])
features_scaled = pd.DataFrame(std_scale.transform(data[numerical_features]), 
                           columns=numerical_features, index=data.index)
data = pd.concat([data[data.columns.drop(numerical_features)], features_scaled], axis=1)

display(data.head(), data.shape)
# Out:
#                                     project  risk  \
# 0  d4a12fad3a1553d1aa8d945c6d8c46e4b733ae5e   1.0
# 1  d4a12fad3a1553d1aa8d945c6d8c46e4b733ae5e   1.0
# 2  d4a12fad3a1553d1aa8d945c6d8c46e4b733ae5e   1.0
# 3  d4a12fad3a1553d1aa8d945c6d8c46e4b733ae5e   0.0
# 4  d4a12fad3a1553d1aa8d945c6d8c46e4b733ae5e   0.0
#
#                         status  has_schedule        scope       office  month  \
# 0  tramitando para contratação             1  Corporativo  Corporativo      3
# 1  tramitando para contratação             1  Corporativo  Corporativo      4
# 2  tramitando para contratação             1  Corporativo  Corporativo      5
# 3                 em andamento             1  Corporativo  Corporativo      6
# 4                 em andamento             1  Corporativo  Corporativo      6
#
#    year  risk_previous1  risk_previous2      ...       secom           day  \
# 0  2015               0               0      ...         0.0 -4.010050e-16
# 1  2015               1               0      ...         0.0 -1.257328e+00
# 2  2015               1               1      ...         0.0 -6.929637e-01
# 3  2015               1               1      ...         0.0  1.338748e+00
# 4  2015               1               1      ...         0.0 -1.821692e+00
#
#    report_word_count  poa_word_count  compliance  estimated_days_finish  \
# 0           0.007585       -0.824473    0.722363               0.000000
# 1          -0.015689       -0.824473    0.722363               0.046109
# 2           0.263596       -0.824473    0.722363               0.020124
# 3          -0.411344        1.192079    0.722363              -0.016255
# 4          -0.364796        0.202135    0.722363               0.004533
#
#    manager_risk_likelihood  manager_project_count  project_risk_likelihood  \
# 0                -0.252429              -0.784835                -0.172296
# 1                 0.593820              -0.784835                 0.749906
# 2                 1.099686              -0.784835                 1.392062
# 3                 1.444595               0.706060                 1.872233
# 4                 1.444595               0.706060                 1.872233
#
#    report_count
# 0      1.947849
# 1      1.947849
# 2      1.947849
# 3      1.947849
# 4      1.947849
#
# [5 rows x 39 columns]
# (1022, 39)

# %% [markdown]
# ## Train/test split

# %%
train_selector = (data.year == 2015) | ((data.year == 2016) & (data.month <= 3))

train = data[train_selector]
test = data[~train_selector & (data.risk >= 0)]
unlabeled = data[data.risk == -1]

print("Training set shape {}".format(train.shape))
print("Test set shape {}".format(test.shape))
print("Unlabeled set shape {}".format(unlabeled.shape))

features = data.columns.drop(['project', 'scope', 'office', 'status', 'risk'])
# Out:
# Training set shape (733, 39)
# Test set shape (229, 39)
# Unlabeled set shape (60, 39)

# %%
'''clfs = [SVC(class_weight='balanced', kernel='rbf', probability=True),
        #LogisticRegression(class_weight='balanced'),
        KNeighborsClassifier(n_neighbors=15),
        GaussianNB(),
        ExtraTreesClassifier(n_estimators=200, class_weight='balanced', random_state=17)]'''

clfs = [GridSearchCV(SVC(class_weight='balanced', probability=True),
                   param_grid=dict(C=[1, 10, 100], gamma=[0.001, 0.0001],
                                   kernel=['rbf']), cv=6, scoring='roc_auc'),
        GridSearchCV(KNeighborsClassifier(n_neighbors=5),
                   param_grid=dict(n_neighbors=[10, 15, 20]), cv=6, scoring='roc_auc'),
        GaussianNB(),
        GridSearchCV(ExtraTreesClassifier(n_estimators=100, class_weight='balanced',
                                          random_state=17),
                   param_grid=dict(n_estimators=[50, 100, 200]), cv=6, scoring='roc_auc')
        ]

scores = util.benchmark(clfs, train[features], train.risk)
print("Scores for each classifier: {}" % scores)
print("Score: %0.3f (+/-%0.03f) for features %r" % (np.mean(scores), np.std(scores) * 2, features.values.tolist()))
util.visualize(train[features], train.risk)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-106d9ddc056c> in <module>()
#      16         ]
#      17
# ---> 18 scores = util.benchmark(clfs, train[features], train.risk)
#      19 print("Scores for each classifier: {}" % scores)
#      20 print("Score: %0.3f (+/-%0.03f) for features %r" % (np.mean(scores), np.std(scores) * 2, features.values.tolist()))
#
# AttributeError: module 'util' has no attribute 'benchmark'

# %%
best_score = 0
best_features = None
for k in range(1, 15):        
    selector = SelectKBest(f_classif, k=k)
    selector.fit(train[features], train['risk'])
    bestk_features = features[selector.get_support()]

    scores = benchmark(clfs, train[bestk_features], train.risk, show_graph=False,
                       show_confusion=False)
    score = np.mean(scores)
    
    if score > best_score:
        best_score = score
        best_features = bestk_features

scores = benchmark(clfs, train[best_features], train.risk)
print(scores)
print("%0.3f (+/-%0.03f) for %r" % (np.mean(scores), np.std(scores) * 2, best_features))
visualize(train[best_features], train.risk)
# Out:
# [0.74632998973892573, 0.73967847939539622, 0.63757798059149728, 0.69410728965213964]
# 0.704 (+/-0.087) for Index(['month', 'não iniciado', 'sem relatório', 'suspenso', 'cenin',
#        'corporativo', 'drh', 'risk_previous1', 'risk_previous2',
#        'risk_previous3', 'project_risk_likelihood', 'report_word_count',
#        'poa_word_count', 'manager_risk_likelihood'],
#       dtype='object')

# %%
lsvc = LinearSVC(C=0.1, penalty="l1", dual=False).fit(train[features], train['risk'])
model_selector = SelectFromModel(lsvc, prefit=True)
X_new = selector.transform(train[features])
model_features = features[model_selector.get_support()]

scores = benchmark(clfs, train[model_features], train.risk)
print(scores)
print("%0.3f (+/-%0.03f) for %r" % (np.mean(scores), np.std(scores) * 2, model_features))
visualize(train[model_features], train.risk)
# Out:
# [0.73945064523168214, 0.71315313883100362, 0.62143792359827488, 0.71570804328307747]
# 0.697 (+/-0.090) for Index(['month', 'year', 'em andamento', 'não iniciado', 'sem relatório',
#        'suspenso', 'compliance', 'report_count', 'has_schedule', 'cenin',
#        'risk_previous1', 'risk_previous2', 'report_word_count',
#        'poa_word_count', 'estimated_days_finish', 'manager_risk_likelihood',
#        'manager_project_count'],
#       dtype='object')

# %%
combined_features = list(set(best_features) | set(model_features))

scores = benchmark(clfs, train[combined_features], train.risk)
print(scores)
print("%0.3f (+/-%0.03f) for %r" % (np.mean(scores), np.std(scores) * 2, combined_features))
visualize(train[combined_features], train.risk)
# Out:
# [0.73673628081029174, 0.71822670706964709, 0.63975854898336415, 0.71229410179785346]
# 0.702 (+/-0.074) for ['report_word_count', 'cenin', 'risk_previous1', 'em andamento', 'compliance', 'poa_word_count', 'has_schedule', 'manager_risk_likelihood', 'report_count', 'corporativo', 'suspenso', 'manager_project_count', 'year', 'month', 'não iniciado', 'project_risk_likelihood', 'sem relatório', 'risk_previous2', 'risk_previous3', 'estimated_days_finish', 'drh']

# %%
selected_features = best_features

# %%
clfs = [
        SVC(C=1, gamma=0.001, class_weight='balanced', probability=True, kernel='rbf'),
        KNeighborsClassifier(n_neighbors=15),
        GaussianNB(),
        ExtraTreesClassifier(n_estimators=200, class_weight='balanced', random_state=17)
        ]

df = pd.DataFrame(columns=('w1', 'w2', 'w3', 'w4', 'mean', 'std'))

i = 0
for w1 in range(1,3):
    for w2 in range(1,3):
        for w3 in range(1,3):
            for w4 in range(1,3):

                if len(set((w1,w2,w3,w4))) == 1: # skip if all weights are equal
                    continue

                eclf = VotingClassifier(
                    estimators=[(type(clf).__name__, clf) for clf in clfs], voting='soft',
                                        weights=[w1,w2,w3,w4])
                scores = cross_val_score(
                                                estimator=eclf,
                                                X=train[selected_features],
                                                y=train.risk,
                                                cv=6,
                                                scoring='roc_auc',
                                                n_jobs=1)

                df.loc[i] = [w1, w2, w3, w4, scores.mean(), scores.std()]
                i += 1

df.sort_values(['mean', 'std'], ascending=[False, False], inplace=True)
#display(df.sort_values(columns=['mean', 'std'], ascending=False, inplace=True))
weights = df.iloc[0][['w1', 'w2', 'w3', 'w4']].values.tolist()
display(df.iloc[0])
# Out:
# w1      2.000000
# w2      2.000000
# w3      1.000000
# w4      2.000000
# mean    0.854008
# std     0.068028
# Name: 12, dtype: float64

# %%
clfs = [
        SVC(class_weight='balanced', probability=True, kernel='rbf'),
        #LogisticRegression(class_weight='balanced'),
        KNeighborsClassifier(n_neighbors=5),
        GaussianNB(),
        ExtraTreesClassifier(n_estimators=100, class_weight='balanced', random_state=17)
        ]

eclf = VotingClassifier(estimators=[(type(clf).__name__, clf) for clf in clfs], 
                          voting='soft', weights=[3,3,1,3])

params = {'SVC__C': [1, 10, 100], 'SVC__gamma': [0.001, 0.0001], 'SVC__kernel': ['rbf'],
          'ExtraTreesClassifier__n_estimators': [50, 100, 200],
          'KNeighborsClassifier__n_neighbors': [10, 15, 20]
         }

grid = GridSearchCV(estimator=eclf, param_grid=params, cv=6, scoring='roc_auc')

scores = benchmark(grid, train[selected_features], train.risk, threshold=0.5)
print("%0.3f (+/-%0.03f) for %r" % (np.mean(scores), np.std(scores) * 2, selected_features))
# Out:
# 0.762 (+/-0.000) for Index(['month', 'não iniciado', 'sem relatório', 'suspenso', 'cenin',
#        'corporativo', 'drh', 'risk_previous1', 'risk_previous2',
#        'risk_previous3', 'project_risk_likelihood', 'report_word_count',
#        'poa_word_count', 'manager_risk_likelihood'],
#       dtype='object')

# %%
grid.best_estimator_.fit(train[selected_features], train.risk)
#predicted = grid.best_estimator_.predict(test[combined_features])
pred_prob_1 = grid.best_estimator_.predict_proba(test[selected_features])[:, 1]
predicted = binarize([pred_prob_1], 0.20)[0]
print("Classification report:\n%s"
              % (metrics.classification_report(test.risk, predicted)))
print("Confusion matrix:\n%s\n" % metrics.confusion_matrix(test.risk, predicted))
# Out:
# Classification report:
#              precision    recall  f1-score   support
#
#         0.0       0.98      0.60      0.74       197
#         1.0       0.27      0.91      0.41        32
#
# avg / total       0.88      0.64      0.70       229
#
# Confusion matrix:
# [[118  79]
#  [  3  29]]

# %%
pred_prob_1 = grid.best_estimator_.predict_proba(unlabeled[selected_features])[:, 1]
predicted = binarize([pred_prob_1], 0.15)[0]
predictions = data.loc[unlabeled[predicted == 1].index]
predictions.drop_duplicates(['project'], inplace=True)
import datetime
predictions.to_csv("risk_%s.csv" % datetime.date.today(), index=False)
display(predictions.head(), predictions.shape)
# Out:
#            scope       office  \
# 41   Corporativo  Corporativo
# 62   Corporativo  Corporativo
# 102  Corporativo  Corporativo
# 135  Corporativo        CENIN
# 179     Setorial           DG
#
#                                                project  \
# 41                          Centro de Tecnologia Norte
# 62                                  Implantação de ECM
# 102                Sistema de Gestão do Relacionamento
# 135  Integração de Informações de Parlamentares – M...
# 179                                          CotasGraf
#
#                                manager        date  risk  month  year  \
# 41         Olival Gomes Barboza Junior  2016-08-01  -1.0      8  2016
# 62      Sandro Heleno de Sene Trindade  2016-08-01  -1.0      8  2016
# 102               Fábio Mesquita Póvoa  2016-08-01  -1.0      8  2016
# 135        José Antônio Ferreira Filho  2016-08-01  -1.0      8  2016
# 179  Expedito Reinaldo da Silva Júnior  2016-08-01  -1.0      8  2016
#
#             status  atividade          ...            risk_previous1  \
# 41   sem relatório        0.0          ...                         0
# 62    em andamento        0.0          ...                         0
# 102  sem relatório        0.0          ...                         0
# 135   em andamento        0.0          ...                         0
# 179  sem relatório        0.0          ...                         1
#
#      risk_previous2  risk_previous3  project_risk_likelihood       day  \
# 41                0               0                 0.025641  17.13933
# 62                0               0                 0.036630  26.00000
# 102               0               0                 0.018315  17.00000
# 135               0               0                 0.007326  26.00000
# 179               1               0                 0.032967   1.00000
#
#      report_word_count  poa_word_count  estimated_days_finish  \
# 41             71.4903       24.650794              206.89418
# 62            123.0000      175.000000             -270.00000
# 102            26.0000      202.000000             -135.00000
# 135           104.0000        1.000000               35.00000
# 179           219.0000       26.000000             -382.00000
#
#      manager_risk_likelihood  manager_project_count
# 41                   0.03321                      1
# 62                   0.04059                      1
# 102                  0.02583                      1
# 135                  0.01107                      1
# 179                  0.03321                      1
#
# [5 rows x 41 columns]
# (28, 41)

# %%
# Build a forest and compute the feature importances
forest = ExtraTreesClassifier(n_estimators=200,
                              random_state=17)

forest.fit(train[selected_features], train.risk)
importances = forest.feature_importances_
std = np.std([tree.feature_importances_ for tree in forest.estimators_],
             axis=0)
indices = np.argsort(importances)#[::-1]

# Print the feature ranking
print("Feature ranking:")

for f in range(train[selected_features].shape[1]):
    print("%d. feature %s (%f)" % (f + 1, selected_features[indices[f]], 
                                   importances[indices[f]]))

# Plot the feature importances of the forest
plt.figure(figsize=(8,8))
#plt.title("Importância das variáveis")
plt.barh(range(train[selected_features].shape[1]), importances[indices],
       color="r", yerr=std[indices], align="center")
plt.yticks(range(train[selected_features].shape[1]),
           [selected_features[i] for i in indices], fontsize=20,)
plt.ylim([-1, train[selected_features].shape[1]])
plt.grid()
plt.show()
# Out:
# Feature ranking:
# 1. feature risk_previous1 (1.000000)
